# %% [markdown]
# # Random otp generator
# - 6 digit
# - after 30 second it will give u a msg of expire

# %%
import random

# %%
import time
otp = random.randint(000000 , 999999)
print(f"Your 6 digit otp is {otp} valid for 30 seconds")
time.sleep(30)
print("OTP has been expired..")
# Out:
# Your 6 digit otp is 883861 valid for 30 seconds
# OTP has been expired..

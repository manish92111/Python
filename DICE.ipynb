# %% [markdown]
# # DICE

# %%
import random

# %%
while True:
    roll = random.randint(1,6)
    print(roll)
    user_input = input("Press Y if u want to roll it again\n").lower()
    if user_input != "y":
        print("Ended..")
        break
    else:
        continue
# Out:
# 3
# Press Y if u want to roll it again
#  y
# 4
